# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv('Placement.csv')
df.head(3)
# Out:
#    cgpa   iq  placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df , x='cgpa', y='iq' , hue='placement')
plt.show()

# %%
x=df.iloc[:,:-1]
x
# Out:
#     cgpa   iq
# 0    6.8  123
# 1    5.9  106
# 2    5.3  121
# 3    7.4  132
# 4    5.8  142
# ..   ...  ...
# 95   4.3  200
# 96   4.4   42
# 97   6.7  182
# 98   6.3  103
# 99   6.2  113
#
# [100 rows x 2 columns]

# %%
y=df['placement']
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x_train,x_test , y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
svc= SVC(kernel='linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.score(x_test, y_test)*100
# Out:
# 95.0

# %%
svc.score(x_train, y_train)*100
# Out:
# 91.25

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=svc)
plt.show()
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
svc= SVC(kernel='poly')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
svc.score(x_test, y_test)*100
# Out:
# 55.00000000000001

# %%
svc.score(x_train, y_train)*100
# Out:
# 55.00000000000001

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=svc)
plt.show()
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
svc= SVC(kernel='rbf')
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc.score(x_test, y_test)*100
# Out:
# 35.0

# %%
svc.score(x_train, y_train)*100
# Out:
# 56.25

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=svc)
plt.show()
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #  In all kernel Linear kernel is best
