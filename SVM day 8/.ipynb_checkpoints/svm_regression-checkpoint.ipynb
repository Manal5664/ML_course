# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVR

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tann22u/placement-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\smc\.cache\kagglehub\datasets\tann22u\placement-dataset\versions\1

# %%
import os

# %%
file=os.listdir(path)
file
# Out:
# ['placement.csv']

# %%
df=pd.read_csv(os.path.join(path, 'placement.csv'))

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=df, x='cgpa', y='package')
plt.show()

# %%
x=df[['cgpa']]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y=df['package']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
svmR=SVR(kernel='linear')
svmR.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
svmR.score(x_test, y_test)*100
# Out:
# 77.06668029575103

# %%
svmR.score(x_train, y_train)*100
# Out:
# 77.45351616879739

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=df, x='cgpa', y='package')
plt.plot(df['cgpa'], svmR.predict(x), color='red')
plt.show()
