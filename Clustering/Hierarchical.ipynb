# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('iris_cluster.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           1           5.1          3.5           1.4          0.2
# 1           2           4.9          3.0           1.4          0.2
# 2           3           4.7          3.2           1.3          0.2

# %% [raw]
# hierarchial clustering work on linearly seperable dataset

# %%
sns.pairplot(data=df )
plt.show()

# %% [markdown]
# use dedogram (to know the clusters)

# %%
# !pip install Scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sys
{sys. executable}
# Out:
# {'C:\\Users\\smc\\AppData\\Local\\Programs\\Python\\Python312\\python.exe'}

# %%
import scipy.cluster.hierarchy as sch

# %%
plt.figure(figsize=(20, 20))
sch.dendrogram(sch.linkage(df,method='single', metric='euclidean'))
plt.savefig('hierarchical cluster.jpg')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac=AgglomerativeClustering(n_clusters=2, linkage='single') 
df['predict']=ac.fit_predict(df)

# %%
df.head(3)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  predict
# 0           1           5.1          3.5           1.4          0.2        1
# 1           2           4.9          3.0           1.4          0.2        1
# 2           3           4.7          3.2           1.3          0.2        1

# %%
sns.pairplot(data=df, hue='predict')
plt.show()
