# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df= pd.read_csv("student_scores.csv")
df.head(5)
# Out:
#    Hours  Score
# 0    1.1     35
# 1    1.5     40
# 2    2.0     45
# 3    2.2     43
# 4    2.5     48

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Hours']],df.Score)
# Out:
# LinearRegression()

# %%
reg.predict([[2]])
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([42.70465962])

# %%
reg.predict([[8]])
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([93.96195397])

# %%
reg.coef_
# Out:
# array([8.54288239])

# %%
reg.intercept_
# Out:
# 25.618894842012224

# %%
y=8.54288239*8+25.618894842012224
y
# Out:
# 93.96195396201223

# %%
d=pd.read_csv("hours_dataset.csv")
p=reg.predict(d)

# %%
d['Score'] = p
d.to_csv('hours_prediction.csv')

# %%
p
# Out:
# 0      38.433218
# 1      42.704660
# 2      46.976101
# 3      51.247542
# 4      55.518983
# 5      64.061866
# 6      68.333307
# 7      72.604748
# 8      77.730477
# 9      88.836225
# 10     72.604748
# 11     89.690513
# 12     93.961954
# 13    102.504836
# 14     68.333307
# Name: Score, dtype: float64

# %%
# %matplotlib inline
plt.xlabel('Hours')
plt.ylabel ('Score')
plt.scatter(df.Hours, df.Score,color='red', marker='+' )
plt.plot(df.Hours , reg.predict(df[['Hours']]), color='blue')
