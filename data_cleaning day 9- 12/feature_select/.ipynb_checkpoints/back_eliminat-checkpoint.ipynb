# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head(3)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     700 non-null    float64
#  1   sex     700 non-null    float64
#  2   bmi     700 non-null    float64
#  3   bp      700 non-null    float64
#  4   s1      700 non-null    float64
#  5   s2      700 non-null    float64
#  6   s3      700 non-null    float64
#  7   s4      700 non-null    float64
#  8   s5      700 non-null    float64
#  9   s6      700 non-null    float64
#  10  target  700 non-null    float64
# dtypes: float64(11)
# memory usage: 60.3 KB

# %%
df.shape
# Out:
# (700, 11)

# %%
x=df.iloc[:,:-1]
y=df['target']

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
fs=SequentialFeatureSelector(lr, k_features=2,forward=True)
fs.fit(x,y)
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ...

# %%
fs.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
fs.k_feature_names_
# Out:
# ('sex', 's3')

# %%
fs.k_score_
# Out:
# 0.017142857142857144

# %% [markdown]
# ## k_features=10
# ('age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6')
# fs.k_score_
# 0.012857142857142855
# ## k_features=9
# ('age', 'sex', 'bmi', 'bp', 's1', 's3', 's4', 's5', 's6')
# fs.k_score_
# 0.015714285714285715
# ## k_features=8
# ('age', 'sex', 'bmi', 'bp', 's3', 's4', 's5', 's6')
# fs.k_score_
# 0.015714285714285715
# ## k_features=7
# ('age', 'sex', 'bmi', 's3', 's4', 's5', 's6')
# fs.k_score_
# 0.015714285714285715
# ## k_features=6
# ('age', 'sex', 'bmi', 's3', 's4', 's6')
# fs.k_score_
# 0.017142857142857144
# ## k_features=5
# ('age', 'sex', 'bmi', 's3', 's4')
# fs.k_score_
# 0.017142857142857144
# ## k_features=4
# ('age', 'sex', 's3', 's4')
# fs.k_score_
# 0.01857142857142857
# ## k_features=3
# ('age', 'sex', 's3')
# fs.k_score_
# 0.017142857142857144
# ## k_features=2
# ('sex', 's3')
# 0.017142857142857144

# %% [markdown]
# ## Use k=4 features: ('age', 'sex', 's3', 's4')
# Because:Accuracy is highest: 0.01857
#
# ## Only 4 features needed (efficient and simple)
