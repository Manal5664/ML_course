# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Placement.csv')
df.head(3)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0

# %%
plt.figure(figsize=(7,5)),
sns.scatterplot(x='cgpa' , y='iq', data=df , hue='placement')
plt.show()

# %%
x=df[['cgpa' , 'iq']]
y=df['placement']

# %%
from sklearn.model_selection import train_test_split

# %%
x_tarin, x_test, y_train,y_test = train_test_split(x, y , test_size=0.2 , random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(x_tarin , y_train)
# Out:
# LogisticRegression()

# %%
log.score(x_test  , y_test)*100
# Out:
# 85.0

# %%
log.predict([[6.0 , 120]])
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
# !pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy() , y.to_numpy(), clf=log)
plt.show()
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [raw]
# we use sigmoid here
# y= 1/1+e power x
# y_pred= m1x1+m2x2+b
# so basically they provide me
# coefficient and intercept

# %%
log.coef_
# Out:
# array([[3.08692655, 0.00887102]])

# %%
log.intercept_
# Out:
# array([-19.61194721])
