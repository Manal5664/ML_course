# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("parvmodi/cgpa-vs-package-in-lpa")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\smc\.cache\kagglehub\datasets\parvmodi\cgpa-vs-package-in-lpa\versions\1

# %%
file=os.listdir(path)
file
# Out:
# ['placement.csv']

# %%
df=pd.read_csv(os.path.join(path, 'placement.csv'))

# %%
df.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
sns.scatterplot(data=df)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df['package']

# %%
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr=LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100 , lr.score(x_train, y_train)*100
# Out:
# (77.30984312051673, 77.58339025733345)

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_test, y_test)*100,dt.score(x_train, y_train)*100
# Out:
# (52.19733481708333, 95.1559200955432)

# %% [raw]
# sv=SVR()
# sv.fit(x_train, y_train)

# %%
sv.score(x_test,y_test)*100, sv.score(x_train  , y_train)*100
# Out:
# (75.94945442913415, 78.16909319813372)

# %%
from sklearn.ensemble import VotingRegressor

# %%
li=[('dt',DecisionTreeRegressor()),('sv', SVR()), ('Li', LinearRegression())]

# %%
vc=VotingRegressor(li, weights=[10,4,7])
vc.fit(x_train, y_train)
# Out:
# VotingRegressor(estimators=[('dt', DecisionTreeRegressor()), ('sv', SVR()),
#                             ('Li', LinearRegression())],
#                 weights=[10, 4, 7])

# %%
vc.score(x_test, y_test)*100, vc.score(x_train, y_train)*100
# Out:
# (72.44294654243724, 90.4457079412907)

# %% [markdown]
# # How to Predict Voting Classifier

# %%
predict= {'dt':dt.predict(x_test), 'sv':sv.predict(x_test), 'linear':lr.predict(x_test),'vc':vc.predict(x_test) }

# %%
df=pd.DataFrame(predict)

# %%
df.head(3)
# Out:
#        dt        sv    linear        vc
# 0  2.9200  2.745462  2.780313  2.840193
# 1  3.2525  3.111375  3.136352  3.186903
# 2  2.9200  3.186923  3.199521  3.064016

# %%
(2.9200+2.745462+2.780313)/3
# Out:
# 2.815258333333333
